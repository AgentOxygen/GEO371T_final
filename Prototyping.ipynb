# %%
import xarray
import datetime

DATA_DIR = "../geo371t_data/"

grid_load = xarray.open_dataset(f"{DATA_DIR}/load_timeseries/load_timeseries.nc")

# %%
grid_load["ercot"].sel(time=slice(datetime.datetime(2021, 2, 1), datetime.datetime(2021, 2, 28))).plot()

# %%
grid_load
# Out:
# <xarray.Dataset>
# Dimensions:   (time: 173111)
# Coordinates:
#   * time      (time) datetime64[ns] 2003-01-01T01:00:00 ... 2022-09-30T23:00:00
# Data variables:
#     coast     (time) float64 ...
#     east      (time) float64 ...
#     far_west  (time) float64 ...
#     north     (time) float64 ...
#     north_c   (time) float64 ...
#     southern  (time) float64 ...
#     south_c   (time) float64 ...
#     west      (time) float64 ...
#     ercot     (time) float64 ...
# Attributes:
#     description:  ERCOT Electrical Grid load (gigawatts)
